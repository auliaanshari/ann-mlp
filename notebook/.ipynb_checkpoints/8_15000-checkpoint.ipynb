# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn import preprocessing
from sklearn.preprocessing import MinMaxScaler

# %%
# Data Train Load dataset
datatrain = pd.read_csv("/home/systemcommand/anggy/app/data/trainanggy.csv", delimiter=',')
datatrain.head()
# Out:
#       T         B    SU1    SU2    RT1    RT2     RT3     RT4     I1     I2  \
# 0  2017   Januari  14835  18172  14183  24728  841756  201048  46800  39938
# 1  2017  Februari  14893  19026  14371  24394  832284  200774  47536  37282
# 2  2017     Maret  13676  17706  13864  23071  789354  197318  41005  35755
# 3  2017     April  15780  20222  15791  26153  893393  224847  47793  38759
# 4  2017       Mei  15698  17508  14863  24681  851205  222635  45794  37655
#
#       N1     N2    N3        J
# 0  56324  32492  5994  1296270
# 1  57218  31412  5329  1284519
# 2  55068  30468  5737  1223022
# 3  63590  34198  6926  1387452
# 4  60998  26452  5915  1323404

# %%
datatrain.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24 entries, 0 to 23
# Data columns (total 14 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   T       24 non-null     int64
#  1   B       24 non-null     object
#  2   SU1     24 non-null     int64
#  3   SU2     24 non-null     int64
#  4   RT1     24 non-null     int64
#  5   RT2     24 non-null     int64
#  6   RT3     24 non-null     int64
#  7   RT4     24 non-null     int64
#  8   I1      24 non-null     int64
#  9   I2      24 non-null     int64
#  10  N1      24 non-null     int64
#  11  N2      24 non-null     int64
#  12  N3      24 non-null     int64
#  13  J       24 non-null     int64
# dtypes: int64(13), object(1)
# memory usage: 2.8+ KB

# %%
# EDA/ data description
this = datatrain.copy()
this.describe()
# Out:
#                  T           SU1           SU2           RT1           RT2  \
# count    24.000000     24.000000     24.000000     24.000000     24.000000
# mean   2017.500000  16104.916667  18290.208333  16534.291667  24995.458333
# std       0.510754   1264.363525   1241.900471   1881.335453   1115.935170
# min    2017.000000  13676.000000  15291.000000  13584.000000  22892.000000
# 25%    2017.000000  15246.500000  17696.500000  15420.250000  24221.500000
# 50%    2017.500000  15957.000000  18305.500000  16122.000000  24905.500000
# 75%    2018.000000  17105.250000  19032.500000  17938.000000  25862.250000
# max    2018.000000  18750.000000  20804.000000  20184.000000  27067.000000
#
#                 RT3            RT4            I1            I2            N1  \
# count      24.00000      24.000000     24.000000     24.000000     24.000000
# mean   852528.62500  250181.791667  49658.750000  41513.708333  62788.500000
# std     33973.08554   29215.222834   3421.754727   4409.177016   4970.613609
# min    774140.00000  197318.000000  41005.000000  33836.000000  54898.000000
# 25%    839388.00000  229978.750000  47423.000000  38483.000000  59764.000000
# 50%    854607.50000  255383.500000  49450.000000  40874.500000  63619.500000
# 75%    875528.50000  271391.000000  52196.750000  44572.750000  65514.750000
# max    911332.00000  295305.000000  56538.000000  49724.000000  74471.000000
#
#                  N2           N3             J
# count     24.000000    24.000000  2.400000e+01
# mean   31665.083333  6312.791667  1.370574e+06
# std     3459.028827   585.891144  7.163533e+04
# min    23525.000000  5329.000000  1.223022e+06
# 25%    29437.000000  5797.750000  1.321748e+06
# 50%    32318.500000  6184.500000  1.379902e+06
# 75%    33680.000000  6865.000000  1.418112e+06
# max    37372.000000  7422.000000  1.482129e+06

# %%
# Preprocessing
train = this.drop(['T','B'],axis=1)

# Preprocessing/ transform(normalizing)
scaler = preprocessing.MinMaxScaler().fit(train)
data_train = scaler.transform(train)

# %%
# Selecting Variables
datax = []
for i in range(len(data_train)):
    tes = data_train[i][:11]
    datax.append(tes)

datay = []
for i in range(len(data_train)):
    tes = data_train[i][-1]
    datay.append(tes)

x = np.array(datax,np.float32)
y = np.array(datay,np.float32)

print(x.shape)
# Out:
# (24, 11)

# %%
# Data Test Load dataset
datatest = pd.read_csv("/home/systemcommand/anggy/app/data/testanggy.csv", delimiter=',')
test = datatest.copy()

# %%
# Preprocessing
testing = test.drop(['T','B'],axis=1)

# Preprocessing/ Transform(normalizing)
scaler = preprocessing.MinMaxScaler().fit(testing)
data_test = scaler.transform(testing)

# %%
# Selecting Variables

datax1 = []
for i in range(len(data_test)):
    tes = data_test[i][:11]
    datax1.append(tes)

datay1 = []
for i in range(len(data_test)):
    tes = data_test[i][-1]
    datay1.append(tes)

xx = np.array(datax1,np.float32)
yy = np.array(datay1,np.float32)

# %%
# Define parameters
n = x.shape[1]
m = 8
M = 1
init_arr_item = 0.0

learning_rate = 0.001
TRAIN_ITER = 15000

# %%
# Make Placeholder 
w = np.ones([m,n], np.float32)*init_arr_item
v = np.ones([M,m], np.float32)*init_arr_item
b_j = np.zeros([m], np.float32)*init_arr_item
b_k = np.zeros([M], np.float32)*init_arr_item

z_pred = np.zeros([y.shape[0], m], np.float32)
y_pred = np.zeros([y.shape[0], M], np.float32)
E = np.zeros(M, np.float32)

v_new = np.zeros([M,m], np.float32)
delta_k = np.zeros(M, np.float32)

w_new = np.zeros([m,n], np.float32)
delta_j = np.zeros(m, np.float32)

# %%
# Define Sigmoid activation function
def f_sigmoid(value):
    return 1.0/(1.0+np.exp(-value))

def f_sigmoid_derivation(value):
    return f_sigmoid(value)*(1-f_sigmoid(value))
  
# Define Linear activation function
def f_linear(value):
    return value

def f_linear_derivation(value):
    return np.ones(value.shape, np.float32)
  
# Hidden Layer activation function wrapper
def f_activation(value):
    return f_sigmoid(value)
  
def f_activation_derivation(value):
    return f_sigmoid_derivation(value)

# Output Layer activation function wrapper
def f_activation_output(value):
    return f_linear(value)

def f_activation_derivation_output(value):
    return f_linear_derivation(value)

# %%
# Feed Forward
def calc_z_j(x_train, w_train, b_j_train):
    for j in range(m):
        z_pred[:,j] = np.dot(x_train,w_train[j,:]) + b_j_train[j]
    
    return z_pred
    
def calc_y_k(z_train, v_train, b_k_train):
    for k in range(M):
        y_pred[:,k] = np.dot(z_train, v_train[k,:]) + b_k_train[k]
    
    return y_pred

# %%
# Calculate Loss
def error_calc(target, output):
    for k in range(M):
        E[k] = 0.5*(target[k] - output[k])**2
    return np.sum(E)

# %%
# Backpropagation
def calc_v_new(v_last, y, y_prediction, z_prediction):
    delta_k = np.transpose(f_activation_derivation_output(y_prediction)*(np.reshape(y, (y.shape[0], 1)) - y_prediction))
        
    for j in range(m):
        v_new[:,j] = v_last[:,j] + learning_rate*np.dot(delta_k,z_prediction[:,j])
            
    return v_new, delta_k


def calc_w_new(w_last, v_new, delta_k, z_prediction, x_input):
    sum_v = np.dot(np.transpose(v_new), delta_k)
    
    delta_j = np.transpose(f_activation_derivation(z_prediction))*sum_v
    
    for i in range(n):
            w_new[:,i] = w_last[:,i] + learning_rate*np.dot(delta_j,x_input[:,i])
            
    return w_new, delta_j
    
def calc_b_k_new(delta_k, b_k_last):
    return b_k_last +  learning_rate*np.sum(delta_k)

def calc_b_j_new(delta_j, b_j_last):
    return b_j_last + learning_rate*np.sum(delta_j)

# %%
# RMSE
def rmse(predictions, targets):
    return 100 - np.sqrt(((predictions - targets) ** 2).mean())

# %%
# Train Model
def train_model(train_count, w_train, v_train, b_j_train, b_k_train, y_train, x_train):
    index = []
    error = []
    for l in range(train_count):
        z_prediction = calc_z_j(x_train, w_train, b_j_train)
        z_prediction = f_activation(z_prediction)
        
        y_prediction = calc_y_k(z_prediction, v_train, b_k_train)
        y_prediction = f_activation_output(y_prediction)
        
        v_train, delta_k = calc_v_new(v_train, y_train, y_prediction, z_prediction)
        w_train, delta_j = calc_w_new(w_train, v_train, delta_k, z_prediction, x_train)
        
        b_k_train = calc_b_k_new(delta_k, b_k_train)
        b_j_train = calc_b_j_new(delta_j, b_j_train)
        
        rms = rmse(y_prediction, y_train)
        
        loss = error_calc(y_train, y_prediction)

        if l % 100 == 0:
            error.append(loss)
            index.append(l)
            print("Iterasi ke-" + str(l) + " Error : " + str(loss))
        
    plt.figure()
    plt.plot(index, error)
    plt.xlabel("Number of iterations")
    plt.ylabel("Cost")
    plt.show()
    
    print('-'*30)
    print('TRAINING MODEL')
    print('-'*30)
    print('\nOutput prediksi hidden layer : ')
    print('-'*30)
    print(z_prediction)
    print('\nOutput prediksi output layer : ')
    print('-'*30)
    print(y_prediction)
    print('\nOutput bobot dari hidden layer ke output layer : ')
    print('-'*30)
    print(v_train)
    print('\nOutput bobot dari input layer ke hidden layer : ')
    print('-'*30)
    print(w_train)
    print('\nOutput bias dari hidden layer ke output layer : ')
    print('-'*30)
    print(b_k_train)
    print('\nOutput bias dari input layer ke hidden layer : ')
    print('-'*30)
    print(b_j_train)
    print('-'*30)
    print()
    print('-'*30)
    print('AKURASI : ' + str(rms) + '%')
    print('-'*30)
    return v_train, w_train, b_k_train, b_j_train

# %%
# Call function 
v, w, b_k, b_j = train_model(TRAIN_ITER, w, v, b_j, b_k, y, x)
# Out:
# Iterasi ke-0 Error : 0.03995795
# Iterasi ke-100 Error : 0.04092052
# Iterasi ke-200 Error : 0.04081175
# Iterasi ke-300 Error : 0.040623404
# Iterasi ke-400 Error : 0.040426616
# Iterasi ke-500 Error : 0.040217962
# Iterasi ke-600 Error : 0.039994206
# Iterasi ke-700 Error : 0.039752178
# Iterasi ke-800 Error : 0.03948887
# Iterasi ke-900 Error : 0.039201386
# Iterasi ke-1000 Error : 0.0388869
# Iterasi ke-1100 Error : 0.038542766
# Iterasi ke-1200 Error : 0.038166393
# Iterasi ke-1300 Error : 0.037755303
# Iterasi ke-1400 Error : 0.0373073
# Iterasi ke-1500 Error : 0.036820263
# Iterasi ke-1600 Error : 0.036292378
# Iterasi ke-1700 Error : 0.035721947
# Iterasi ke-1800 Error : 0.03510775
# Iterasi ke-1900 Error : 0.034448765
# Iterasi ke-2000 Error : 0.033744395
# Iterasi ke-2100 Error : 0.032994438
# Iterasi ke-2200 Error : 0.032199085
# Iterasi ke-2300 Error : 0.031359106
# Iterasi ke-2400 Error : 0.030475726
# Iterasi ke-2500 Error : 0.029550679
# Iterasi ke-2600 Error : 0.02858616
# Iterasi ke-2700 Error : 0.027585063
# Iterasi ke-2800 Error : 0.026550636
# Iterasi ke-2900 Error : 0.025486846
# Iterasi ke-3000 Error : 0.024397885
# Iterasi ke-3100 Error : 0.023288606
# Iterasi ke-3200 Error : 0.02216421
# Iterasi ke-3300 Error : 0.021030156
# Iterasi ke-3400 Error : 0.01989214
# Iterasi ke-3500 Error : 0.018756084
# Iterasi ke-3600 Error : 0.017627921
# Iterasi ke-3700 Error : 0.016513612
# Iterasi ke-3800 Error : 0.015418867
# Iterasi ke-3900 Error : 0.014349161
# Iterasi ke-4000 Error : 0.013309766
# Iterasi ke-4100 Error : 0.012305263
# Iterasi ke-4200 Error : 0.011339846
# Iterasi ke-4300 Error : 0.01041707
# Iterasi ke-4400 Error : 0.0095398715
# Iterasi ke-4500 Error : 0.008710426
# Iterasi ke-4600 Error : 0.007930359
# Iterasi ke-4700 Error : 0.0072004977
# Iterasi ke-4800 Error : 0.006521034
# Iterasi ke-4900 Error : 0.005891601
# Iterasi ke-5000 Error : 0.0053112386
# Iterasi ke-5100 Error : 0.004778543
# Iterasi ke-5200 Error : 0.0042916713
# Iterasi ke-5300 Error : 0.0038485292
# Iterasi ke-5400 Error : 0.0034466404
# Iterasi ke-5500 Error : 0.0030835213
# Iterasi ke-5600 Error : 0.0027564613
# Iterasi ke-5700 Error : 0.0024627396
# Iterasi ke-5800 Error : 0.002199711
# Iterasi ke-5900 Error : 0.0019646885
# Iterasi ke-6000 Error : 0.0017551451
# Iterasi ke-6100 Error : 0.0015686556
# Iterasi ke-6200 Error : 0.0014029527
# Iterasi ke-6300 Error : 0.0012558771
# Iterasi ke-6400 Error : 0.0011254702
# Iterasi ke-6500 Error : 0.0010099395
# Iterasi ke-6600 Error : 0.000907624
# Iterasi ke-6700 Error : 0.000817029
# Iterasi ke-6800 Error : 0.00073682325
# Iterasi ke-6900 Error : 0.0006657881
# Iterasi ke-7000 Error : 0.0006028438
# Iterasi ke-7100 Error : 0.0005470391
# Iterasi ke-7200 Error : 0.00049752137
# Iterasi ke-7300 Error : 0.00045353136
# Iterasi ke-7400 Error : 0.00041442082
# Iterasi ke-7500 Error : 0.00037958205
# Iterasi ke-7600 Error : 0.00034852247
# Iterasi ke-7700 Error : 0.00032076915
# Iterasi ke-7800 Error : 0.00029593942
# Iterasi ke-7900 Error : 0.0002736777
# Iterasi ke-8000 Error : 0.0002536834
# Iterasi ke-8100 Error : 0.00023568812
# Iterasi ke-8200 Error : 0.00021945228
# Iterasi ke-8300 Error : 0.00020478133
# Iterasi ke-8400 Error : 0.00019148474
# Iterasi ke-8500 Error : 0.0001794149
# Iterasi ke-8600 Error : 0.00016842425
# Iterasi ke-8700 Error : 0.00015839777
# Iterasi ke-8800 Error : 0.00014922011
# Iterasi ke-8900 Error : 0.00014080403
# Iterasi ke-9000 Error : 0.00013307136
# Iterasi ke-9100 Error : 0.00012595029
# Iterasi ke-9200 Error : 0.00011935817
# Iterasi ke-9300 Error : 0.000113260576
# Iterasi ke-9400 Error : 0.00010759373
# Iterasi ke-9500 Error : 0.00010233308
# Iterasi ke-9600 Error : 9.7410484e-05
# Iterasi ke-9700 Error : 9.280564e-05
# Iterasi ke-9800 Error : 8.849616e-05
# Iterasi ke-9900 Error : 8.444553e-05
# Iterasi ke-10000 Error : 8.0618396e-05
# Iterasi ke-10100 Error : 7.702347e-05
# Iterasi ke-10200 Error : 7.3618976e-05
# Iterasi ke-10300 Error : 7.038758e-05
# Iterasi ke-10400 Error : 6.734072e-05
# Iterasi ke-10500 Error : 6.44235e-05
# Iterasi ke-10600 Error : 6.164894e-05
# Iterasi ke-10700 Error : 5.900407e-05
# Iterasi ke-10800 Error : 5.6477984e-05
# Iterasi ke-10900 Error : 5.404929e-05
# Iterasi ke-11000 Error : 5.1733372e-05
# Iterasi ke-11100 Error : 4.951679e-05
# Iterasi ke-11200 Error : 4.7381225e-05
# Iterasi ke-11300 Error : 4.533132e-05
# Iterasi ke-11400 Error : 4.335449e-05
# Iterasi ke-11500 Error : 4.146297e-05
# Iterasi ke-11600 Error : 3.962743e-05
# Iterasi ke-11700 Error : 3.7857302e-05
# Iterasi ke-11800 Error : 3.6166133e-05
# Iterasi ke-11900 Error : 3.4513607e-05
# Iterasi ke-12000 Error : 3.2936478e-05
# Iterasi ke-12100 Error : 3.1395284e-05
# Iterasi ke-12200 Error : 2.9922367e-05
# Iterasi ke-12300 Error : 2.8492033e-05
# Iterasi ke-12400 Error : 2.710024e-05
# Iterasi ke-12500 Error : 2.5766396e-05
# Iterasi ke-12600 Error : 2.4471214e-05
# Iterasi ke-12700 Error : 2.3228115e-05
# Iterasi ke-12800 Error : 2.20277e-05
# Iterasi ke-12900 Error : 2.0857593e-05
# Iterasi ke-13000 Error : 1.9720916e-05
# Iterasi ke-13100 Error : 1.863864e-05
# Iterasi ke-13200 Error : 1.759115e-05
# Iterasi ke-13300 Error : 1.6572578e-05
# Iterasi ke-13400 Error : 1.559037e-05
# Iterasi ke-13500 Error : 1.4653005e-05
# Iterasi ke-13600 Error : 1.37453235e-05
# Iterasi ke-13700 Error : 1.28715e-05
# Iterasi ke-13800 Error : 1.2026956e-05
# Iterasi ke-13900 Error : 1.1219536e-05
# Iterasi ke-14000 Error : 1.0447251e-05
# Iterasi ke-14100 Error : 9.708804e-06
# Iterasi ke-14200 Error : 8.991859e-06
# Iterasi ke-14300 Error : 8.30484e-06
# Iterasi ke-14400 Error : 7.6525785e-06
# Iterasi ke-14500 Error : 7.0341425e-06
# Iterasi ke-14600 Error : 6.4426154e-06
# Iterasi ke-14700 Error : 5.8778814e-06
# Iterasi ke-14800 Error : 5.335152e-06
# Iterasi ke-14900 Error : 4.825741e-06
# ------------------------------
# TRAINING MODEL
# ------------------------------
#
# Output prediksi hidden layer :
# ------------------------------
# [[0.46713683 0.46713683 0.46713683 0.46713683 0.46713683 0.46713683
#   0.46713683 0.46713683]
#  [0.45297515 0.45297515 0.45297515 0.45297515 0.45297515 0.45297515
#   0.45297515 0.45297515]
#  [0.3809524  0.3809524  0.3809524  0.3809524  0.3809524  0.3809524
#   0.3809524  0.3809524 ]
#  [0.58268154 0.58268154 0.58268154 0.58268154 0.58268154 0.58268154
#   0.58268154 0.58268154]
#  [0.49655062 0.49655062 0.49655062 0.49655062 0.49655062 0.49655062
#   0.49655062 0.49655062]
#  [0.47181588 0.47181588 0.47181588 0.47181588 0.47181588 0.47181588
#   0.47181588 0.47181588]
#  [0.55349034 0.55349034 0.55349034 0.55349034 0.55349034 0.55349034
#   0.55349034 0.55349034]
#  [0.53340536 0.53340536 0.53340536 0.53340536 0.53340536 0.53340536
#   0.53340536 0.53340536]
#  [0.63932467 0.63932467 0.63932467 0.63932467 0.63932467 0.63932467
#   0.63932467 0.63932467]
#  [0.4347096  0.4347096  0.4347096  0.4347096  0.4347096  0.4347096
#   0.4347096  0.4347096 ]
#  [0.6194044  0.6194044  0.6194044  0.6194044  0.6194044  0.6194044
#   0.6194044  0.6194044 ]
#  [0.5432091  0.5432091  0.5432091  0.5432091  0.5432091  0.5432091
#   0.5432091  0.5432091 ]
#  [0.5097378  0.5097378  0.5097378  0.5097378  0.5097378  0.5097378
#   0.5097378  0.5097378 ]
#  [0.5736045  0.5736045  0.5736045  0.5736045  0.5736045  0.5736045
#   0.5736045  0.5736045 ]
#  [0.54115266 0.54115266 0.54115266 0.54115266 0.54115266 0.54115266
#   0.54115266 0.54115266]
#  [0.6147254  0.6147254  0.6147254  0.6147254  0.6147254  0.6147254
#   0.6147254  0.6147254 ]
#  [0.60721505 0.60721505 0.60721505 0.60721505 0.60721505 0.60721505
#   0.60721505 0.60721505]
#  [0.6614084  0.6614084  0.6614084  0.6614084  0.6614084  0.6614084
#   0.6614084  0.6614084 ]
#  [0.44888833 0.44888833 0.44888833 0.44888833 0.44888833 0.44888833
#   0.44888833 0.44888833]
#  [0.63101953 0.63101953 0.63101953 0.63101953 0.63101953 0.63101953
#   0.63101953 0.63101953]
#  [0.7075712  0.7075712  0.7075712  0.7075712  0.7075712  0.7075712
#   0.7075712  0.7075712 ]
#  [0.6420211  0.6420211  0.6420211  0.6420211  0.6420211  0.6420211
#   0.6420211  0.6420211 ]
#  [0.70628303 0.70628303 0.70628303 0.70628303 0.70628303 0.70628303
#   0.70628303 0.70628303]
#  [0.6856635  0.6856635  0.6856635  0.6856635  0.6856635  0.6856635
#   0.6856635  0.6856635 ]]
#
# Output prediksi output layer :
# ------------------------------
# [[0.28564286]
#  [0.24356389]
#  [0.02956069]
#  [0.6289642 ]
#  [0.3730409 ]
#  [0.29954588]
#  [0.5422275 ]
#  [0.48254848]
#  [0.79726946]
#  [0.189291  ]
#  [0.7380798 ]
#  [0.5116786 ]
#  [0.4122243 ]
#  [0.6019933 ]
#  [0.50556827]
#  [0.724177  ]
#  [0.70186126]
#  [0.8628876 ]
#  [0.23142064]
#  [0.7725922 ]
#  [1.0000523 ]
#  [0.8052815 ]
#  [0.99622476]
#  [0.9349574 ]]
#
# Output bobot dari hidden layer ke output layer :
# ------------------------------
# [[0.37141773 0.37141773 0.37141773 0.37141773 0.37141773 0.37141773
#   0.37141773 0.37141773]]
#
# Output bobot dari input layer ke hidden layer :
# ------------------------------
# [[0.25168228 0.0782731  0.15902592 0.16499186 0.27461192 0.2619189
#   0.10201888 0.10858862 0.1966129  0.06264174 0.10835747]
#  [0.25168228 0.0782731  0.15902592 0.16499186 0.27461192 0.2619189
#   0.10201888 0.10858862 0.1966129  0.06264174 0.10835747]
#  [0.25168228 0.0782731  0.15902592 0.16499186 0.27461192 0.2619189
#   0.10201888 0.10858862 0.1966129  0.06264174 0.10835747]
#  [0.25168228 0.0782731  0.15902592 0.16499186 0.27461192 0.2619189
#   0.10201888 0.10858862 0.1966129  0.06264174 0.10835747]
#  [0.25168228 0.0782731  0.15902592 0.16499186 0.27461192 0.2619189
#   0.10201888 0.10858862 0.1966129  0.06264174 0.10835747]
#  [0.25168228 0.0782731  0.15902592 0.16499186 0.27461192 0.2619189
#   0.10201888 0.10858862 0.1966129  0.06264174 0.10835747]
#  [0.25168228 0.0782731  0.15902592 0.16499186 0.27461192 0.2619189
#   0.10201888 0.10858862 0.1966129  0.06264174 0.10835747]
#  [0.25168228 0.0782731  0.15902592 0.16499186 0.27461192 0.2619189
#   0.10201888 0.10858862 0.1966129  0.06264174 0.10835747]]
#
# Output bias dari hidden layer ke output layer :
# ------------------------------
# [-1.1023774]
#
# Output bias dari input layer ke hidden layer :
# ------------------------------
# [-0.63142926 -0.63142926 -0.63142926 -0.63142926 -0.63142926 -0.63142926
#  -0.63142926 -0.63142926]
# ------------------------------
#
# ------------------------------
# AKURASI : 99.62044754624367%
# ------------------------------

# %%
# Test Model
def test(x_test, y_test, w, v,  b_j, b_k):
    z_prediction = np.dot(x_test, np.transpose(w)) + b_j
    f_z_prediction = f_activation(z_prediction)
    
    y_prediction = np.dot(f_z_prediction, np.transpose(v)) + b_k
    f_y_prediction =  f_activation_output(y_prediction)
    
    rms = rmse(f_y_prediction, y_test)
    
    print('-'*30)
    print('TESTING MODEL')
    print('-'*30)
    print('\nOutput prediksi hidden layer : ')
    print('-'*30)
    print(z_prediction)
    print('\nOutput prediksi output layer : ')
    print('-'*30)
    print(y_prediction)
    print('\nOutput bobot dari hidden layer ke output layer : ')
    print('-'*30)
    print(v)
    print('\nOutput bobot dari input layer ke hidden layer : ')
    print('-'*30)
    print(w)
    print('\nOutput bias dari hidden layer ke output layer : ')
    print('-'*30)
    print(b_k)
    print('\nOutput bias dari input layer ke hidden layer : ')
    print('-'*30)
    print(b_j)
    print('-'*30)
    print()
    print('-'*30)
    print('AKURASI : ' + str(rms) + '%')
    print('-'*30)
    return f_y_prediction

# %%
# Call function
y_prediction_test = np.zeros(len(xx), np.float32)
y_prediction_test = test(xx, yy, w, v,  b_j, b_k)
# Out:
# ------------------------------
# TESTING MODEL
# ------------------------------
#
# Output prediksi hidden layer :
# ------------------------------
# [[ 0.06644863  0.06644863  0.06644863  0.06644863  0.06644863  0.06644863
#    0.06644863  0.06644863]
#  [ 0.06302273  0.06302273  0.06302273  0.06302273  0.06302273  0.06302273
#    0.06302273  0.06302273]
#  [-0.33116305 -0.33116305 -0.33116305 -0.33116305 -0.33116305 -0.33116305
#   -0.33116305 -0.33116305]
#  [ 0.07245582  0.07245582  0.07245582  0.07245582  0.07245582  0.07245582
#    0.07245582  0.07245582]
#  [ 0.18786734  0.18786734  0.18786734  0.18786734  0.18786734  0.18786734
#    0.18786734  0.18786734]
#  [ 0.7234022   0.7234022   0.7234022   0.7234022   0.7234022   0.7234022
#    0.7234022   0.7234022 ]
#  [-0.61415255 -0.61415255 -0.61415255 -0.61415255 -0.61415255 -0.61415255
#   -0.61415255 -0.61415255]
#  [ 0.49728638  0.49728638  0.49728638  0.49728638  0.49728638  0.49728638
#    0.49728638  0.49728638]
#  [ 0.09223807  0.09223807  0.09223807  0.09223807  0.09223807  0.09223807
#    0.09223807  0.09223807]
#  [ 0.17371714  0.17371714  0.17371714  0.17371714  0.17371714  0.17371714
#    0.17371714  0.17371714]
#  [ 0.88342434  0.88342434  0.88342434  0.88342434  0.88342434  0.88342434
#    0.88342434  0.88342434]
#  [ 0.2700585   0.2700585   0.2700585   0.2700585   0.2700585   0.2700585
#    0.2700585   0.2700585 ]]
#
# Output prediksi output layer :
# ------------------------------
# [[ 0.4326359 ]
#  [ 0.43009353]
#  [ 0.13951778]
#  [ 0.43709278]
#  [ 0.522439  ]
#  [ 0.8983927 ]
#  [-0.05910206]
#  [ 0.74526656]
#  [ 0.45176256]
#  [ 0.5120131 ]
#  [ 0.99994016]
#  [ 0.58269227]]
#
# Output bobot dari hidden layer ke output layer :
# ------------------------------
# [[0.37141773 0.37141773 0.37141773 0.37141773 0.37141773 0.37141773
#   0.37141773 0.37141773]]
#
# Output bobot dari input layer ke hidden layer :
# ------------------------------
# [[0.25168228 0.0782731  0.15902592 0.16499186 0.27461192 0.2619189
#   0.10201888 0.10858862 0.1966129  0.06264174 0.10835747]
#  [0.25168228 0.0782731  0.15902592 0.16499186 0.27461192 0.2619189
#   0.10201888 0.10858862 0.1966129  0.06264174 0.10835747]
#  [0.25168228 0.0782731  0.15902592 0.16499186 0.27461192 0.2619189
#   0.10201888 0.10858862 0.1966129  0.06264174 0.10835747]
#  [0.25168228 0.0782731  0.15902592 0.16499186 0.27461192 0.2619189
#   0.10201888 0.10858862 0.1966129  0.06264174 0.10835747]
#  [0.25168228 0.0782731  0.15902592 0.16499186 0.27461192 0.2619189
#   0.10201888 0.10858862 0.1966129  0.06264174 0.10835747]
#  [0.25168228 0.0782731  0.15902592 0.16499186 0.27461192 0.2619189
#   0.10201888 0.10858862 0.1966129  0.06264174 0.10835747]
#  [0.25168228 0.0782731  0.15902592 0.16499186 0.27461192 0.2619189
#   0.10201888 0.10858862 0.1966129  0.06264174 0.10835747]
#  [0.25168228 0.0782731  0.15902592 0.16499186 0.27461192 0.2619189
#   0.10201888 0.10858862 0.1966129  0.06264174 0.10835747]]
#
# Output bias dari hidden layer ke output layer :
# ------------------------------
# [-1.1023774]
#
# Output bias dari input layer ke hidden layer :
# ------------------------------
# [-0.63142926 -0.63142926 -0.63142926 -0.63142926 -0.63142926 -0.63142926
#  -0.63142926 -0.63142926]
# ------------------------------
#
# ------------------------------
# AKURASI : 99.61367163062096%
# ------------------------------

# %%
# Denormalize prediction
j = datatest['J']
denorm = []
for i in range(len(data_test)):
    y[i] = y_prediction_test[i] * (j.max(axis=0) - j.min(axis=0)) + j.min(axis=0) 
    denorm.append(y[i])
print(denorm)
# Out:
# [1493577.2, 1492754.0, 1398662.4, 1495020.5, 1522656.5, 1644394.5, 1334347.1, 1594810.5, 1499770.8, 1519280.5, 1677276.6, 1542167.1]

# %%
# Output prediction File
submission = pd.DataFrame({
    "Time" : datatest['B'],
    "Result": denorm
    })

submission.head(5)

# Export it in a 'Comma Separated Values' (CSV) file
submission.to_csv(r'/home/systemcommand/anggy/app/data/pred(11-8-1-15000).csv', index=False)
# Creating a link to download the .csv file we created
from IPython.display import FileLink
FileLink(r'/home/systemcommand/anggy/app/data/pred(11-8-1-15000).csv')
# Out:
# /home/systemcommand/anggy/app/data/pred(11-8-1-15000).csv

# %%
# Output Truth File
submission = pd.DataFrame({
    "Time" : datatest['B'],
    "Result": datatest['J']
    })

submission.head(5)

# Export it in a 'Comma Separated Values' (CSV) file
submission.to_csv(r'/home/systemcommand/anggy/app/data/truth.csv', index=False)
# Creating a link to download the .csv file we created
from IPython.display import FileLink
FileLink(r'/home/systemcommand/anggy/app/data/truth.csv')
# Out:
# /home/systemcommand/anggy/app/data/truth.csv

# %%
# Plot prediction and truth data
dataa = pd.read_csv('/home/systemcommand/anggy/app/data/truth.csv')
datac = pd.read_csv('/home/systemcommand/anggy/app/data/pred(11-8-1-15000).csv')

x = dataa['Result']
y = dataa['Time']

x2 = datac['Result']
y2 = datac['Time']

plt.figure(figsize=(16,8))
plt.scatter(y2,x2,c='red')
plt.plot(y2,x2,c='red', label="Prediction")
plt.scatter(y,x,c='blue')
plt.plot(y,x,c='blue', label="Actual")
plt.legend(loc='upper left', fontsize = 20)
plt.ylabel('prediction', fontsize = 15)
plt.xlabel('period', fontsize = 15)
plt.title('Perbandingan data aktual dan prediksi 2019', fontsize = 20)
plt.xticks()
plt.show()
