# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn import preprocessing
from sklearn.preprocessing import MinMaxScaler

# %%
# Data Train Load dataset
datatrain = pd.read_csv("/home/systemcommand/anggy/app/data/trainanggy.csv", delimiter=',')
datatrain.head()
# Out:
#       T         B    SU1    SU2    RT1    RT2     RT3     RT4     I1     I2  \
# 0  2017   Januari  14835  18172  14183  24728  841756  201048  46800  39938
# 1  2017  Februari  14893  19026  14371  24394  832284  200774  47536  37282
# 2  2017     Maret  13676  17706  13864  23071  789354  197318  41005  35755
# 3  2017     April  15780  20222  15791  26153  893393  224847  47793  38759
# 4  2017       Mei  15698  17508  14863  24681  851205  222635  45794  37655
#
#       N1     N2    N3        J
# 0  56324  32492  5994  1296270
# 1  57218  31412  5329  1284519
# 2  55068  30468  5737  1223022
# 3  63590  34198  6926  1387452
# 4  60998  26452  5915  1323404

# %%
datatrain.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24 entries, 0 to 23
# Data columns (total 14 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   T       24 non-null     int64
#  1   B       24 non-null     object
#  2   SU1     24 non-null     int64
#  3   SU2     24 non-null     int64
#  4   RT1     24 non-null     int64
#  5   RT2     24 non-null     int64
#  6   RT3     24 non-null     int64
#  7   RT4     24 non-null     int64
#  8   I1      24 non-null     int64
#  9   I2      24 non-null     int64
#  10  N1      24 non-null     int64
#  11  N2      24 non-null     int64
#  12  N3      24 non-null     int64
#  13  J       24 non-null     int64
# dtypes: int64(13), object(1)
# memory usage: 2.8+ KB

# %%
# EDA/ data description
this = datatrain.copy()
this.describe()
# Out:
#                  T           SU1           SU2           RT1           RT2  \
# count    24.000000     24.000000     24.000000     24.000000     24.000000
# mean   2017.500000  16104.916667  18290.208333  16534.291667  24995.458333
# std       0.510754   1264.363525   1241.900471   1881.335453   1115.935170
# min    2017.000000  13676.000000  15291.000000  13584.000000  22892.000000
# 25%    2017.000000  15246.500000  17696.500000  15420.250000  24221.500000
# 50%    2017.500000  15957.000000  18305.500000  16122.000000  24905.500000
# 75%    2018.000000  17105.250000  19032.500000  17938.000000  25862.250000
# max    2018.000000  18750.000000  20804.000000  20184.000000  27067.000000
#
#                 RT3            RT4            I1            I2            N1  \
# count      24.00000      24.000000     24.000000     24.000000     24.000000
# mean   852528.62500  250181.791667  49658.750000  41513.708333  62788.500000
# std     33973.08554   29215.222834   3421.754727   4409.177016   4970.613609
# min    774140.00000  197318.000000  41005.000000  33836.000000  54898.000000
# 25%    839388.00000  229978.750000  47423.000000  38483.000000  59764.000000
# 50%    854607.50000  255383.500000  49450.000000  40874.500000  63619.500000
# 75%    875528.50000  271391.000000  52196.750000  44572.750000  65514.750000
# max    911332.00000  295305.000000  56538.000000  49724.000000  74471.000000
#
#                  N2           N3             J
# count     24.000000    24.000000  2.400000e+01
# mean   31665.083333  6312.791667  1.370574e+06
# std     3459.028827   585.891144  7.163533e+04
# min    23525.000000  5329.000000  1.223022e+06
# 25%    29437.000000  5797.750000  1.321748e+06
# 50%    32318.500000  6184.500000  1.379902e+06
# 75%    33680.000000  6865.000000  1.418112e+06
# max    37372.000000  7422.000000  1.482129e+06

# %%
# Preprocessing
train = this.drop(['T','B'],axis=1)

# Preprocessing/ transform(normalizing)
scaler = preprocessing.MinMaxScaler().fit(train)
data_train = scaler.transform(train)

# %%
# Selecting Variables
datax = []
for i in range(len(data_train)):
    tes = data_train[i][:11]
    datax.append(tes)

datay = []
for i in range(len(data_train)):
    tes = data_train[i][-1]
    datay.append(tes)

x = np.array(datax,np.float32)
y = np.array(datay,np.float32)

print(x.shape)
# Out:
# (24, 11)

# %%
# Data Test Load dataset
datatest = pd.read_csv("/home/systemcommand/anggy/app/data/testanggy.csv", delimiter=',')
test = datatest.copy()

# %%
# Preprocessing
testing = test.drop(['T','B'],axis=1)

# Preprocessing/ Transform(normalizing)
scaler = preprocessing.MinMaxScaler().fit(testing)
data_test = scaler.transform(testing)

# %%
# Selecting Variables

datax1 = []
for i in range(len(data_test)):
    tes = data_test[i][:11]
    datax1.append(tes)

datay1 = []
for i in range(len(data_test)):
    tes = data_test[i][-1]
    datay1.append(tes)

xx = np.array(datax1,np.float32)
yy = np.array(datay1,np.float32)

# %%
# Define parameters
n = x.shape[1]
m = 11
M = 1
init_arr_item = 0.0

learning_rate = 0.001
TRAIN_ITER = 10400

# %%
# Make Placeholder 
w = np.ones([m,n], np.float32)*init_arr_item
v = np.ones([M,m], np.float32)*init_arr_item
b_j = np.zeros([m], np.float32)*init_arr_item
b_k = np.zeros([M], np.float32)*init_arr_item

z_pred = np.zeros([y.shape[0], m], np.float32)
y_pred = np.zeros([y.shape[0], M], np.float32)
E = np.zeros(M, np.float32)

v_new = np.zeros([M,m], np.float32)
delta_k = np.zeros(M, np.float32)

w_new = np.zeros([m,n], np.float32)
delta_j = np.zeros(m, np.float32)

# %%
# Define Sigmoid activation function
def f_sigmoid(value):
    return 1.0/(1.0+np.exp(-value))

def f_sigmoid_derivation(value):
    return f_sigmoid(value)*(1-f_sigmoid(value))
  
# Define Linear activation function
def f_linear(value):
    return value

def f_linear_derivation(value):
    return np.ones(value.shape, np.float32)
  
# Hidden Layer activation function wrapper
def f_activation(value):
    return f_sigmoid(value)
  
def f_activation_derivation(value):
    return f_sigmoid_derivation(value)

# Output Layer activation function wrapper
def f_activation_output(value):
    return f_linear(value)

def f_activation_derivation_output(value):
    return f_linear_derivation(value)

# %%
# Feed Forward
def calc_z_j(x_train, w_train, b_j_train):
    for j in range(m):
        z_pred[:,j] = np.dot(x_train,w_train[j,:]) + b_j_train[j]
    
    return z_pred
    
def calc_y_k(z_train, v_train, b_k_train):
    for k in range(M):
        y_pred[:,k] = np.dot(z_train, v_train[k,:]) + b_k_train[k]
    
    return y_pred

# %%
# Calculate Loss
def error_calc(target, output):
    for k in range(M):
        E[k] = 0.5*(target[k] - output[k])**2
    return np.sum(E)

# %%
# Backpropagation
def calc_v_new(v_last, y, y_prediction, z_prediction):
    delta_k = np.transpose(f_activation_derivation_output(y_prediction)*(np.reshape(y, (y.shape[0], 1)) - y_prediction))
        
    for j in range(m):
        v_new[:,j] = v_last[:,j] + learning_rate*np.dot(delta_k,z_prediction[:,j])
            
    return v_new, delta_k


def calc_w_new(w_last, v_new, delta_k, z_prediction, x_input):
    sum_v = np.dot(np.transpose(v_new), delta_k)
    
    delta_j = np.transpose(f_activation_derivation(z_prediction))*sum_v
    
    for i in range(n):
            w_new[:,i] = w_last[:,i] + learning_rate*np.dot(delta_j,x_input[:,i])
            
    return w_new, delta_j
    
def calc_b_k_new(delta_k, b_k_last):
    return b_k_last +  learning_rate*np.sum(delta_k)

def calc_b_j_new(delta_j, b_j_last):
    return b_j_last + learning_rate*np.sum(delta_j)

# %%
# RMSE
def rmse(predictions, targets):
    return 100 - np.sqrt(((predictions - targets) ** 2).mean())

# %%
# Train Model
def train_model(train_count, w_train, v_train, b_j_train, b_k_train, y_train, x_train):
    index = []
    error = []
    for l in range(train_count):
        z_prediction = calc_z_j(x_train, w_train, b_j_train)
        z_prediction = f_activation(z_prediction)
        
        y_prediction = calc_y_k(z_prediction, v_train, b_k_train)
        y_prediction = f_activation_output(y_prediction)
        
        v_train, delta_k = calc_v_new(v_train, y_train, y_prediction, z_prediction)
        w_train, delta_j = calc_w_new(w_train, v_train, delta_k, z_prediction, x_train)
        
        b_k_train = calc_b_k_new(delta_k, b_k_train)
        b_j_train = calc_b_j_new(delta_j, b_j_train)
        
        rms = rmse(y_prediction, y_train)
        
        loss = error_calc(y_train, y_prediction)

        if l % 100 == 0:
            error.append(loss)
            index.append(l)
            print("Iterasi ke-" + str(l) + " Error : " + str(loss))
        
        if loss == 0.0001:
            break
        
    plt.figure()
    plt.plot(index, error)
    plt.xlabel("Number of iterations")
    plt.ylabel("Cost")
    plt.show()
    
    print('-'*30)
    print('TRAINING MODEL')
    print('-'*30)
    print('\nOutput prediksi hidden layer : ')
    print('-'*30)
    print(z_prediction)
    print('\nOutput prediksi output layer : ')
    print('-'*30)
    print(y_prediction)
    print('\nOutput bobot dari hidden layer ke output layer : ')
    print('-'*30)
    print(v_train)
    print('\nOutput bobot dari input layer ke hidden layer : ')
    print('-'*30)
    print(w_train)
    print('\nOutput bias dari hidden layer ke output layer : ')
    print('-'*30)
    print(b_k_train)
    print('\nOutput bias dari input layer ke hidden layer : ')
    print('-'*30)
    print(b_j_train)
    print('-'*30)
    print()
    print('-'*30)
    print('AKURASI : ' + str(rms) + '%')
    print('-'*30)
    return v_train, w_train, b_k_train, b_j_train

# %%
# Call function 
v, w, b_k, b_j = train_model(TRAIN_ITER, w, v, b_j, b_k, y, x)
# Out:
# Iterasi ke-0 Error : 0.03995795
# Iterasi ke-100 Error : 0.04098945
# Iterasi ke-200 Error : 0.040838506
# Iterasi ke-300 Error : 0.040674135
# Iterasi ke-400 Error : 0.040503766
# Iterasi ke-500 Error : 0.040324856
# Iterasi ke-600 Error : 0.040135022
# Iterasi ke-700 Error : 0.039931923
# Iterasi ke-800 Error : 0.03971328
# Iterasi ke-900 Error : 0.039476898
# Iterasi ke-1000 Error : 0.039220612
# Iterasi ke-1100 Error : 0.03894236
# Iterasi ke-1200 Error : 0.038639985
# Iterasi ke-1300 Error : 0.03831153
# Iterasi ke-1400 Error : 0.037955042
# Iterasi ke-1500 Error : 0.037568633
# Iterasi ke-1600 Error : 0.03715048
# Iterasi ke-1700 Error : 0.036698956
# Iterasi ke-1800 Error : 0.03621245
# Iterasi ke-1900 Error : 0.035689596
# Iterasi ke-2000 Error : 0.035129108
# Iterasi ke-2100 Error : 0.034530025
# Iterasi ke-2200 Error : 0.033891484
# Iterasi ke-2300 Error : 0.03321297
# Iterasi ke-2400 Error : 0.03249421
# Iterasi ke-2500 Error : 0.03173536
# Iterasi ke-2600 Error : 0.030936828
# Iterasi ke-2700 Error : 0.030099386
# Iterasi ke-2800 Error : 0.029224306
# Iterasi ke-2900 Error : 0.028313164
# Iterasi ke-3000 Error : 0.027368125
# Iterasi ke-3100 Error : 0.026391657
# Iterasi ke-3200 Error : 0.02538677
# Iterasi ke-3300 Error : 0.024356915
# Iterasi ke-3400 Error : 0.023305956
# Iterasi ke-3500 Error : 0.022238119
# Iterasi ke-3600 Error : 0.021158025
# Iterasi ke-3700 Error : 0.020070601
# Iterasi ke-3800 Error : 0.018981077
# Iterasi ke-3900 Error : 0.017894669
# Iterasi ke-4000 Error : 0.016816929
# Iterasi ke-4100 Error : 0.015753174
# Iterasi ke-4200 Error : 0.014708752
# Iterasi ke-4300 Error : 0.013688707
# Iterasi ke-4400 Error : 0.012697903
# Iterasi ke-4500 Error : 0.011740672
# Iterasi ke-4600 Error : 0.010820915
# Iterasi ke-4700 Error : 0.009942013
# Iterasi ke-4800 Error : 0.009106654
# Iterasi ke-4900 Error : 0.0083170375
# Iterasi ke-5000 Error : 0.007574532
# Iterasi ke-5100 Error : 0.006879988
# Iterasi ke-5200 Error : 0.0062335622
# Iterasi ke-5300 Error : 0.0056349556
# Iterasi ke-5400 Error : 0.005083139
# Iterasi ke-5500 Error : 0.0045768493
# Iterasi ke-5600 Error : 0.0041142236
# Iterasi ke-5700 Error : 0.003693275
# Iterasi ke-5800 Error : 0.003311632
# Iterasi ke-5900 Error : 0.0029668864
# Iterasi ke-6000 Error : 0.002656425
# Iterasi ke-6100 Error : 0.0023776656
# Iterasi ke-6200 Error : 0.0021280353
# Iterasi ke-6300 Error : 0.0019049873
# Iterasi ke-6400 Error : 0.001706095
# Iterasi ke-6500 Error : 0.001529063
# Iterasi ke-6600 Error : 0.0013716852
# Iterasi ke-6700 Error : 0.0012319302
# Iterasi ke-6800 Error : 0.0011079663
# Iterasi ke-6900 Error : 0.0009980487
# Iterasi ke-7000 Error : 0.00090061844
# Iterasi ke-7100 Error : 0.00081427494
# Iterasi ke-7200 Error : 0.00073771586
# Iterasi ke-7300 Error : 0.00066984846
# Iterasi ke-7400 Error : 0.0006096264
# Iterasi ke-7500 Error : 0.00055612985
# Iterasi ke-7600 Error : 0.00050859264
# Iterasi ke-7700 Error : 0.00046628268
# Iterasi ke-7800 Error : 0.00042858697
# Iterasi ke-7900 Error : 0.0003949486
.6816569 -0.6816569 -0.6816569 -0.6816569 -0.6816569]
# ------------------------------
#
# ------------------------------
# AKURASI : 99.62231501936913%
# ------------------------------

# %%
# Test Model
def test(x_test, y_test, w, v,  b_j, b_k):
    z_prediction = np.dot(x_test, np.transpose(w)) + b_j
    f_z_prediction = f_activation(z_prediction)
    
    y_prediction = np.dot(f_z_prediction, np.transpose(v)) + b_k
    f_y_prediction =  f_activation_output(y_prediction)
    
    rms = rmse(f_y_prediction, y_test)
    
    print('-'*30)
    print('TESTING MODEL')
    print('-'*30)
    print('\nOutput prediksi hidden layer : ')
    print('-'*30)
    print(z_prediction)
    print('\nOutput prediksi output layer : ')
    print('-'*30)
    print(y_prediction)
    print('\nOutput bobot dari hidden layer ke output layer : ')
    print('-'*30)
    print(v)
    print('\nOutput bobot dari input layer ke hidden layer : ')
    print('-'*30)
    print(w)
    print('\nOutput bias dari hidden layer ke output layer : ')
    print('-'*30)
    print(b_k)
    print('\nOutput bias dari input layer ke hidden layer : ')
    print('-'*30)
    print(b_j)
    print('-'*30)
    print()
    print('-'*30)
    print('AKURASI : ' + str(rms) + '%')
    print('-'*30)
    return f_y_prediction

# %%
# Call function
y_prediction_test = np.zeros(len(xx), np.float32)
y_prediction_test = test(xx, yy, w, v,  b_j, b_k)
# Out:
# ------------------------------
# TESTING MODEL
# ------------------------------
#
# Output prediksi hidden layer :
# ------------------------------
# [[-0.07166272 -0.07166272 -0.07166272 -0.07166272 -0.07166272 -0.07166272
#   -0.07166272 -0.07166272 -0.07166266 -0.07166266 -0.07166266]
#  [-0.05101669 -0.05101669 -0.05101669 -0.05101669 -0.05101669 -0.05101669
#   -0.05101669 -0.05101669 -0.05101669 -0.05101669 -0.05101669]
#  [-0.41946965 -0.41946965 -0.41946965 -0.41946965 -0.41946965 -0.41946965
#   -0.41946965 -0.41946965 -0.41946968 -0.41946968 -0.41946965]
#  [-0.06478399 -0.06478399 -0.06478399 -0.06478399 -0.06478399 -0.06478399
#   -0.06478399 -0.06478399 -0.06478405 -0.06478405 -0.06478399]
#  [ 0.01939207  0.01939207  0.01939207  0.01939207  0.01939207  0.01939207
#    0.01939207  0.01939207  0.01939201  0.01939201  0.01939207]
#  [ 0.46291     0.46291     0.46291     0.46291     0.46291     0.46291
#    0.46291     0.46291     0.46291     0.46291     0.46291   ]
#  [-0.6623503  -0.6623503  -0.6623503  -0.6623503  -0.6623503  -0.6623503
#   -0.6623503  -0.6623503  -0.6623503  -0.6623503  -0.6623503 ]
#  [ 0.3311482   0.3311482   0.3311482   0.3311482   0.3311482   0.3311482
#    0.3311482   0.3311482   0.3311482   0.3311482   0.3311482 ]
#  [-0.0510385  -0.0510385  -0.0510385  -0.0510385  -0.0510385  -0.0510385
#   -0.0510385  -0.0510385  -0.0510385  -0.0510385  -0.0510385 ]
#  [ 0.02204227  0.02204227  0.02204227  0.02204227  0.02204227  0.02204227
#    0.02204227  0.02204227  0.02204227  0.02204227  0.02204227]
#  [ 0.6524603   0.6524603   0.6524603   0.6524603   0.6524603   0.6524603
#    0.6524603   0.6524603   0.6524603   0.6524603   0.6524603 ]
#  [ 0.09687591  0.09687591  0.09687591  0.09687591  0.09687591  0.09687591
#    0.09687591  0.09687591  0.09687591  0.09687591  0.09687591]]
#
# Output prediksi output layer :
# ------------------------------
# [[ 0.42939603]
#  [ 0.446208  ]
#  [ 0.1508112 ]
#  [ 0.43499637]
#  [ 0.50358653]
#  [ 0.8584883 ]
#  [-0.03317213]
#  [ 0.75525   ]
#  [ 0.44619024]
#  [ 0.50574636]
#  [ 1.0014853 ]
#  [ 0.5666801 ]]
#
# Output bobot dari hidden layer ke output layer :
# ------------------------------
# [[0.29638857 0.29638857 0.29638857 0.29638857 0.29638857 0.29638857
#   0.29638857 0.29638857 0.29638854 0.29638854 0.29638854]]
#
# Output bobot dari input layer ke hidden layer :
# ------------------------------
# [[0.19976865 0.05398342 0.15654217 0.15456028 0.20539153 0.21214221
#   0.10430262 0.11792541 0.164251   0.07145186 0.1210888 ]
#  [0.19976865 0.05398342 0.15654217 0.15456028 0.20539153 0.21214221
#   0.10430262 0.11792541 0.164251   0.07145186 0.1210888 ]
#  [0.19976865 0.05398342 0.15654217 0.15456028 0.20539153 0.21214221
#   0.10430262 0.11792541 0.164251   0.07145186 0.1210888 ]
#  [0.19976865 0.05398342 0.15654217 0.15456028 0.20539153 0.21214221
#   0.10430262 0.11792541 0.164251   0.07145186 0.1210888 ]
#  [0.19976865 0.05398342 0.15654217 0.15456028 0.20539153 0.21214221
#   0.10430262 0.11792541 0.164251   0.07145186 0.1210888 ]
#  [0.19976865 0.05398342 0.15654217 0.15456028 0.20539153 0.21214221
#   0.10430262 0.11792541 0.164251   0.07145186 0.1210888 ]
#  [0.19976865 0.05398342 0.15654217 0.15456028 0.20539153 0.21214221
#   0.10430262 0.11792541 0.164251   0.07145186 0.1210888 ]
#  [0.19976865 0.05398342 0.15654217 0.15456028 0.20539153 0.21214221
#   0.10430262 0.11792541 0.164251   0.07145186 0.1210888 ]
#  [0.19976865 0.05398341 0.15654217 0.15456027 0.20539154 0.21214221
#   0.10430262 0.11792541 0.16425098 0.07145186 0.1210888 ]
#  [0.19976865 0.05398341 0.15654217 0.15456027 0.20539154 0.21214221
#   0.10430262 0.11792541 0.16425098 0.07145186 0.1210888 ]
#  [0.19976865 0.05398342 0.15654217 0.15456028 0.20539154 0.21214221
#   0.10430262 0.11792541 0.164251   0.07145186 0.1210888 ]]
#
# Output bias dari hidden layer ke output layer :
# ------------------------------
# [-1.1423559]
#
# Output bias dari input layer ke hidden layer :
# ------------------------------
# [-0.6816569 -0.6816569 -0.6816569 -0.6816569 -0.6816569 -0.6816569
#  -0.6816569 -0.6816569 -0.6816569 -0.6816569 -0.6816569]
# ------------------------------
#
# ------------------------------
# AKURASI : 99.6204462647438%
# ------------------------------

# %%
# Denormalize prediction
j = datatest['J']
denorm = []
for i in range(len(data_test)):
    y[i] = y_prediction_test[i] * (j.max(axis=0) - j.min(axis=0)) + j.min(axis=0) 
    denorm.append(y[i])
print(denorm)
# Out:
# [1492528.1, 1497972.0, 1402319.4, 1494341.6, 1516551.9, 1631473.0, 1342743.5, 1598043.2, 1497966.2, 1517251.2, 1677777.0, 1536982.2]

# %%
# Output prediction File
submission = pd.DataFrame({
    "Time" : datatest['B'],
    "Truth" : datatest['J'],
    "Prediction": denorm
    })

submission.head(5)

# Export it in a 'Comma Separated Values' (CSV) file
submission.to_csv(r'/home/systemcommand/anggy/app/data/pred(11-11-1-10400).csv', index=False)
# Creating a link to download the .csv file we created
from IPython.display import FileLink
FileLink(r'/home/systemcommand/anggy/app/data/pred(11-11-1-10400).csv')
# Out:
# /home/systemcommand/anggy/app/data/pred(11-11-1-10400).csv

# %%
# Plot prediction and truth data
dataa = pd.read_csv('/home/systemcommand/anggy/app/data/pred(11-11-1-10400).csv')

x = dataa['Truth']
x2 = dataa['Prediction']
y = dataa['Time']

plt.figure(figsize=(16,8))
plt.scatter(y,x2,c='red')
plt.plot(y,x2,c='red', label="Prediction")
plt.scatter(y,x,c='blue')
plt.plot(y,x,c='blue', label="Actual")
plt.legend(loc='upper left', fontsize = 20)
plt.ylabel('prediction', fontsize = 15)
plt.xlabel('period', fontsize = 15)
plt.title('Perbandingan data aktual dan prediksi 2019', fontsize = 20)
plt.xticks()
plt.show()
